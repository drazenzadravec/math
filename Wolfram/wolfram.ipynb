# %% [markdown]
# ### Wolfram

# %%
Sin[Pi/2]
# Out:
# 1

# %%
Plot3D[Sin[x y], {x, -Pi, Pi}, {y, -Pi, Pi}]
# Out:
# -Graphics3D-

# %%
sol := Integrate[1/(1 + x^3), x]

# %%
TeXForm[sol]
# Out:
# -\frac{1}{6} \log \left(x^2-x+1\right)+\frac{1}{3} \log (x+1)+\frac{\tan\
#
# >   ^{-1}\left(\frac{2 x-1}{\sqrt{3}}\right)}{\sqrt{3}}

# %%
fun:= Sin[Sqrt[x^2 + y^2]]/Sqrt[x^2 + y^2]
Plot3D[fun, {x, -5*Pi, 5*Pi}, {y, -5*Pi, 5*Pi},
    PlotPoints -> 100, BoxRatios -> {1, 1, 0.2},
    PlotRange -> All]
# Out:
# -Graphics3D-

# %%
equ := 1/(1 + x^3)

# %%
TeXForm[equ]
# Out:
# \frac{1}{x^3+1}

# %%
w := 2^x + x - 5

# %%
TeXForm[w]
# Out:
# x+2^x-5

# %% [markdown]
# Lambert W Function

# %% [markdown]
# Evaluate 2^x + x = 5

# %%
5 - (ProductLog[32 * Log[2.]] / Log[2.])
# Out:
# 1.71562

# %%
Solve[2^x + x == 5, x]
# Out:
# Solve::ifun: Inverse functions are being used by Solve, so some solutions may not be found; use Reduce for complete solution information.
#        5 Log[2] - ProductLog[32 Log[2]]
# {{x -> --------------------------------}}
#                     Log[2]

# %%
((5 * Log[2.]) / Log[2.]) - (ProductLog[32 * Log[2.]] / Log[2.])
# Out:
# 1.71562
